# %% [markdown]
# <a href="https://colab.research.google.com/github/nandinishreegogineni-debug/myproject/blob/main/Dental_Xray_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import numpy as np
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install ultralytics opencv-python numpy pandas matplotlib pillow torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.7 MB/s eta 0:00:00
# ...

# %%
# !unzip "/content/USE CASE - 01.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.23a1c00b27f0dca04da80158ec7b8d42_8.jpg
#   inflating: USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.23a1c00b27f0dca04da80158ec7b8d42_9.jpg
#   inflating: USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_10.jpg
#   inflating: USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_11.jpg
#   inflating: USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_12.jpg
#   inflating: USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_13.jpg
#   inflating: USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_15.jpg
# ...

# %%
# !ls
# Out:
#  sample_data  'USE CASE - 01'  'USE CASE - 01.zip'

# %%
import torch
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch import nn, optim

transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])

train_data = datasets.ImageFolder(
    "/content/USE CASE - 01/Segmented Dental Radiography/train",
    transform=transform
)

val_data = datasets.ImageFolder(
    "/content/USE CASE - 01/Segmented Dental Radiography/valid",
    transform=transform
)

test_data = datasets.ImageFolder(
    "/content/USE CASE - 01/Segmented Dental Radiography/test",
    transform=transform
)

train_loader = DataLoader(train_data,batch_size=8,shuffle=True)
val_loader = DataLoader(val_data,batch_size=8)
test_loader = DataLoader(test_data,batch_size=8)

model = torchvision.models.resnet18(pretrained=True)
model.fc = nn.Linear(512,5)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for epoch in range(2):

    model.train()
    total_loss = 0

    for images,labels in train_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs,labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print("Epoch:",epoch+1,"Loss:",total_loss)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26351/4082267759.py in <cell line: 0>()
#       9         labels = labels.to(device)
#      10
# ---> 11         outputs = model(images)
#      12         loss = criterion(outputs,labels)
#      13
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
# !git config --global user.name "nandinishreegogineni-debug"
# !git config --global user.email "nandinishreegogineni@gmail.com"

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git add .

# %%
# !git add Dental_Xray_AI.ipynb
# Out:
# fatal: pathspec 'Dental_Xray_AI.ipynb' did not match any files

# %%
# !git commit -m "Adding project files"
# Out:
# Streaming output truncated to the last 5000 lines.
#  create mode 100644 USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.23a1c00b27f0dca04da80158ec7b8d42_8.jpg
#  create mode 100644 USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.23a1c00b27f0dca04da80158ec7b8d42_9.jpg
#  create mode 100644 USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_10.jpg
#  create mode 100644 USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_11.jpg
#  create mode 100644 USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_12.jpg
#  create mode 100644 USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_13.jpg
#  create mode 100644 USE CASE - 01/Segmented Dental Radiography/train/Normal/0852_jpg.rf.4891de2ccb22146c2256f048c5385e1c_15.jpg
# ...

# %%
# !git remote add origin https://github.com/nandinishreegogineni-debug/repo.git

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
